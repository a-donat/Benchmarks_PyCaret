# %% [markdown]
# <a href="https://colab.research.google.com/github/a-donat/Benchmarks_PyCaret/blob/main/Predicting_Airline_Satisfaction.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # I. Set-Up

# %% [markdown]
# ## I.A. Import Libraries and Download Data

# %%
! pip install kaggle
! mkdir ~/.kaggle
! cp kaggle.json ~/.kaggle/
! chmod 600 ~/.kaggle/kaggle.json
! kaggle datasets download -d teejmahal20/airline-passenger-satisfaction
! unzip '/content/airline-passenger-satisfaction.zip' -d '/content/data'

# %%
! pip install pycaret

# %%
#import matplotlib.pyplot as plt
#import seaborn as sns
import VisualizeDataAbbrev as viz

import numpy as np
import pandas as pd
from pycaret.classification import *
from sklearn.model_selection import train_test_split

# %% [markdown]
# ## I.B. Load Data and Check Data Integrity

# %%
ds_df = pd.read_csv("/content/data/train.csv")

# %%
ds_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 103904 entries, 0 to 103903
# Data columns (total 25 columns):
#  #   Column                             Non-Null Count   Dtype
# ---  ------                             --------------   -----
#  0   Unnamed: 0                         103904 non-null  int64
#  1   id                                 103904 non-null  int64
#  2   Gender                             103904 non-null  object
#  3   Customer Type                      103904 non-null  object
#  4   Age                                103904 non-null  int64
#  5   Type of Travel                     103904 non-null  object
#  6   Class                              103904 non-null  object
#  7   Flight Distance                    103904 non-null  int64
#  8   Inflight wifi service              103904 non-null  int64
#  9   Departure/Arrival time convenient  103904 non-null  int64
#  10  Ease of Online booking             103904 non-null  int64
# ...

# %%
ds_df.nunique()
# Out:
# Unnamed: 0                           103904
# id                                   103904
# Gender                                    2
# Customer Type                             2
# Age                                      75
# Type of Travel                            2
# Class                                     3
# Flight Distance                        3802
# Inflight wifi service                     6
# Departure/Arrival time convenient         6
# Ease of Online booking                    6
# Gate location                             6
# Food and drink                            6
# Online boarding                           6
# Seat comfort                              6
# Inflight entertainment                    6
# On-board service                          6
# Leg room service                          6
# Baggage handling                          5
# Checkin service                           6
# Inflight service                          6
# ...

# %%
ds_df["satisfaction"].value_counts()
# Out:
# neutral or dissatisfied    58879
# satisfied                  45025
# Name: satisfaction, dtype: int64

# %%
ds_df = ds_df[list(ds_df)[2:]].copy()

# %%
ds_df.describe().round(5)
# Out:
#                 Age  Flight Distance  Inflight wifi service  \
# count  103904.00000     103904.00000           103904.00000
# mean       39.37971       1189.44838                2.72968
# std        15.11496        997.14728                1.32783
# min         7.00000         31.00000                0.00000
# 25%        27.00000        414.00000                2.00000
# 50%        40.00000        843.00000                3.00000
# 75%        51.00000       1743.00000                4.00000
# max        85.00000       4983.00000                5.00000
#
#        Departure/Arrival time convenient  Ease of Online booking  \
# count                       103904.00000            103904.00000
# mean                             3.06030                 2.75690
# std                              1.52508                 1.39893
# min                              0.00000                 0.00000
# 25%                              2.00000                 2.00000
# ...

# %% [markdown]
# # II. Preprocessing

# %%
'''ro_train_df, ro_test_df = train_test_split(
    ro_df, test_size=0.20, stratify=ro_df["Occupancy"], random_state=1)'''

# %% [markdown]
# # III. Create Models

# %%
exp_clf101 = setup(data=ds_df, target = "satisfaction", session_id=123)
# Out:
# <style type="text/css">
# #T_e259e_row12_col1 {
#   background-color: lightgreen;
# }
# </style>
# <table id="T_e259e" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_e259e_level0_col0" class="col_heading level0 col0" >Description</th>
#       <th id="T_e259e_level0_col1" class="col_heading level0 col1" >Value</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_e259e_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_e259e_row0_col0" class="data row0 col0" >Session id</td>
#       <td id="T_e259e_row0_col1" class="data row0 col1" >123</td>
#     </tr>
#     <tr>
#       <th id="T_e259e_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_e259e_row1_col0" class="data row1 col0" >Target</td>
#       <td id="T_e259e_row1_col1" class="data row1 col1" >satisfaction</td>
#     </tr>
#     <tr>
#       <th id="T_e259e_level0_row2" class="row_heading level0 row2" >2</th>
# ...

# %%
best_model = compare_models(fold=5)
# Out:
# <style type="text/css">
# #T_ad951 th {
#   text-align: left;
# }
# ...
