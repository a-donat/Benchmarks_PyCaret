# %% [markdown]
# <a href="https://colab.research.google.com/github/a-donat/Benchmarks_PyCaret/blob/main/Predicting_Rice_Type.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # I. Set-Up

# %% [markdown]
# ## I.A. Import Libraries and Download Data

# %%
! pip install kaggle
! mkdir ~/.kaggle
! cp kaggle.json ~/.kaggle/
! chmod 600 ~/.kaggle/kaggle.json
! kaggle datasets download -d mssmartypants/rice-type-classification
! unzip '/content/rice-type-classification.zip' -d '/content/data'

# %%
! pip install pycaret

# %%
#import matplotlib.pyplot as plt
#import seaborn as sns
import VisualizeDataAbbrev as viz

import numpy as np
import pandas as pd
from pycaret.classification import *
from sklearn.model_selection import train_test_split

# %% [markdown]
# ## I.B. Load Data and Check Data Integrity

# %%
ds_df = pd.read_csv("/content/data/riceClassification.csv")

# %%
ds_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 18185 entries, 0 to 18184
# Data columns (total 12 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   id               18185 non-null  int64
#  1   Area             18185 non-null  int64
#  2   MajorAxisLength  18185 non-null  float64
#  3   MinorAxisLength  18185 non-null  float64
#  4   Eccentricity     18185 non-null  float64
#  5   ConvexArea       18185 non-null  int64
#  6   EquivDiameter    18185 non-null  float64
#  7   Extent           18185 non-null  float64
#  8   Perimeter        18185 non-null  float64
#  9   Roundness        18185 non-null  float64
#  10  AspectRation     18185 non-null  float64
#  11  Class            18185 non-null  int64
# dtypes: float64(8), int64(4)
# memory usage: 1.7 MB

# %%
ds_df.nunique()
# Out:
# id                 18185
# Area                5343
# MajorAxisLength    18185
# MinorAxisLength    18185
# Eccentricity       18185
# ConvexArea          5450
# EquivDiameter       5343
# Extent             18007
# Perimeter          16246
# Roundness          18184
# AspectRation       18185
# Class                  2
# dtype: int64

# %%
ds_df["Class"].value_counts()
# Out:
# 1    9985
# 0    8200
# Name: Class, dtype: int64

# %%
ds_df = ds_df[[c for c in list(ds_df) if c != "id"]].copy()

# %%
ds_df.describe().round(5)
# Out:
#               Area  MajorAxisLength  MinorAxisLength  Eccentricity  \
# count  18185.00000      18185.00000      18185.00000   18185.00000
# mean    7036.49299        151.68075         59.80785       0.91541
# std     1467.19715         12.37640         10.06165       0.03058
# min     2522.00000         74.13311         34.40989       0.67665
# 25%     5962.00000        145.67591         51.39315       0.89162
# 50%     6660.00000        153.88375         55.72429       0.92326
# 75%     8423.00000        160.05621         70.15659       0.94137
# max    10210.00000        183.21143         82.55076       0.96677
#
#         ConvexArea  EquivDiameter       Extent    Perimeter    Roundness  \
# count  18185.00000    18185.00000  18185.00000  18185.00000  18185.00000
# mean    7225.81787       94.13295      0.61665    351.60695      0.70800
# std     1502.00657        9.90625      0.10439     29.50062      0.06731
# min     2579.00000       56.66666      0.38324    197.01500      0.17459
# 25%     6125.00000       87.12666      0.53853    333.99000      0.65096
# 50%     6843.00000       92.08570      0.60119    353.08800      0.70194
# 75%     8645.00000      103.55915      0.69566    373.00300      0.76928
# max    11008.00000      114.01656      0.88657    508.51100      0.90475
#
#        AspectRation        Class
# count   18185.00000  18185.00000
# mean        2.59908      0.54908
# std         0.43484      0.49760
# min         1.35813      0.00000
# 25%         2.20853      0.00000
# 50%         2.60297      1.00000
# 75%         2.96410      1.00000
# max         3.91184      1.00000

# %% [markdown]
# # II. Preprocessing

# %%
train_df, test_df = train_test_split(
    ds_df, test_size=0.20, stratify=ds_df["Class"], random_state=1)

# %% [markdown]
# # III. Create Models

# %%
exp_clf101 = setup(data=train_df, target = "Class", session_id=123)
# Out:
# <style type="text/css">
# #T_f9570_row8_col1 {
#   background-color: lightgreen;
# }
# </style>
# <table id="T_
8_col4, #T_4eea1_row8_col5, #T_4eea1_row8_col6, #T_4eea1_row8_col7, #T_4eea1_row9_col0, #T_4eea1_row9_col1, #T_4eea1_row9_col2, #T_4eea1_row9_col3, #T_4eea1_row9_col4, #T_4eea1_row9_col5, #T_4eea1_row9_col6, #T_4eea1_row9_col7, #T_4eea1_row10_col0, #T_4eea1_row10_col1, #T_4eea1_row10_col2, #T_4eea1_row10_col3, #T_4eea1_row10_col4, #T_4eea1_row10_col5, #T_4eea1_row10_col6, #T_4eea1_row10_col7, #T_4eea1_row11_col0, #T_4eea1_row11_col1, #T_4eea1_row11_col2, #T_4eea1_row11_col3, #T_4eea1_row11_col4, #T_4eea1_row11_col5, #T_4eea1_row11_col6, #T_4eea1_row11_col7, #T_4eea1_row12_col0, #T_4eea1_row12_col1, #T_4eea1_row12_col2, #T_4eea1_row12_col3, #T_4eea1_row12_col4, #T_4eea1_row12_col5, #T_4eea1_row12_col6, #T_4eea1_row12_col7, #T_4eea1_row13_col0, #T_4eea1_row13_col1, #T_4eea1_row13_col2, #T_4eea1_row13_col3, #T_4eea1_row13_col4, #T_4eea1_row13_col5, #T_4eea1_row13_col6, #T_4eea1_row13_col7, #T_4eea1_row14_col0, #T_4eea1_row14_col1, #T_4eea1_row14_col2, #T_4eea1_row14_col4, #T_4eea1_row14_col5, #T_4eea1_row14_col6, #T_4eea1_row14_col7 {
#   text-align: left;
# }
# #T_4eea1_row0_col1, #T_4eea1_row0_col4, #T_4eea1_row0_col5, #T_4eea1_row0_col6, #T_4eea1_row0_col7, #T_4eea1_row6_col2, #T_4eea1_row14_col3 {
#   text-align: left;
#   background-color: yellow;
# }
# #T_4eea1_row0_col8, #T_4eea1_row1_col8, #T_4eea1_row2_col8, #T_4eea1_row3_col8, #T_4eea1_row4_col8, #T_4eea1_row5_col8, #T_4eea1_row6_col8, #T_4eea1_row7_col8, #T_4eea1_row9_col8, #T_4eea1_row10_col8, #T_4eea1_row11_col8, #T_4eea1_row12_col8, #T_4eea1_row13_col8, #T_4eea1_row14_col8 {
#   text-align: left;
#   background-color: lightgrey;
# }
# #T_4eea1_row8_col8 {
#   text-align: left;
#   background-color: yellow;
#   background-color: lightgrey;
# }
# </style>
# <table id="T_4eea1" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_4eea1_level0_col0" class="col_heading level0 col0" >Model</th>
#       <th id="T_4eea1_level0_col1" class="col_heading level0 col1" >Accuracy</th>
#       <th id="T_4eea1_level0_col2" class="col_heading level0 col2" >AUC</th>
#       <th id="T_4eea1_level0_col3" class="col_heading level0 col3" >Recall</th>
#       <th id="T_4eea1_level0_col4" class="col_heading level0 col4" >Prec.</th>
#       <th id="T_4eea1_level0_col5" class="col_heading level0 col5" >F1</th>
#       <th id="T_4eea1_level0_col6" class="col_heading level0 col6" >Kappa</th>
#       <th id="T_4eea1_level0_col7" class="col_heading level0 col7" >MCC</th>
#       <th id="T_4eea1_level0_col8" class="col_heading level0 col8" >TT (Sec)</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_4eea1_level0_row0" class="row_heading level0 row0" >et</th>
#       <td id="T_4eea1_row0_col0" class="data row0 col0" >Extra Trees Classifier</td>
#       <td id="T_4eea1_row0_col1" class="data row0 col1" >0.9901</td>
#       <td id="T_4eea1_row0_col2" class="data row0 col2" >0.9987</td>
#       <td id="T_4eea1_row0_col3" class="data row0 col3" >0.9921</td>
#       <td id="T_4eea1_row0_col4" class="data row0 col4" >0.9898</td>
#       <td id="T_4eea1_row0_col5" class="data row0 col5" >0.9910</td>
#       <td id="T_4eea1_row0_col6" class="data row0 col6" >0.9800</td>
#       <td id="T_4eea1_row0_col7" class="data row0 col7" >0.9800</td>
#       <td id="T_4eea1_row0_col8" class="data row0 col8" >0.7200</td>
#     </tr>
#     <tr>
#       <th id="T_4eea1_level0_row1" class="row_heading level0 row1" >lr</th>
#       <td id="T_4eea1_row1_col0" class="data row1 col0" >Logistic Regression</td>
#       <td id="T_4eea1_row1_col1" class="data row1 col1" >0.9899</td>
#       <td id="T_4eea1_row1_col2" class="data row1 col2" >0.9988</td>
#       <td id="T_4eea1_row1_col3" class="data row1 col3" >0.9928</td>
#       <td id="T_4eea1_row1_col4" class="data row1 col4" >0.9888</td>
#       <td id="T_4eea1_row1_col5" class="data row1 col5" >0.9908</td>
#       <td id="T_4eea1_row1_col6" class="data row1 col6" >0.9796</td>
#       <td id="T_4eea1_row1_col7" class="data row1 col7" >0.9796</td>
#       <td id="T_4eea1_row1_col8" class="data row1 col8" >1.2380</td>
#     </tr>
#     <tr>
#       <th id="T_4eea1_level0_row2" class="row_heading level0 row2" >gbc</th>
#       <td id="T_4eea1_row2_col0" class="data row2 col0" >Gradient Boosting Classifier</td>
#       <td id="T_4eea1_row2_col1" class="data row2 col1" >0.9898</td>
#       <td id="T_4eea1_row2_col2" class="data row2 col2" >0.9982</td>
#       <td id="T_4eea1_row2_col3" class="data row2 col3" >0.9918</td>
#       <td id="T_4eea1_row2_col4" class="data row2 col4" >0.9897</td>
#       <td id="T_4eea1_row2_col5" class="data row2 col5" >0.9907</td>
#       <td id="T_4eea1_row2_col6" class="data row2 col6" >0.9794</td>
#       <td id="T_4eea1_row2_col7" class="data row2 col7" >0.9794</td>
#       <td id="T_4eea1_row2_col8" class="data row2 col8" >3.1920</td>
#     </tr>
#     <tr>
#       <th id="T_4eea1_level0_row3" class="row_heading level0 row3" >xgboost</th>
#       <td id="T_4eea1_row3_col0" class="data row3 col0" >Extreme Gradient Boosting</td>
#       <td id="T_4eea1_row3_col1" class="data row3 col1" >0.9898</td>
#       <td id="T_4eea1_row3_col2" class="data row3 col2" >0.9988</td>
#       <td id="T_4eea1_row3_col3" class="data row3 col3" >0.9920</td>
#       <td id="T_4eea1_row3_col4" class="data row3 col4" >0.9895</td>
#       <td id="T_4eea1_row3_col5" class="data row3 col5" >0.9907</td>
#       <td id="T_4eea1_row3_col6" class="data row3 col6" >0.9794</td>
#       <td id="T_4eea1_row3_col7" class="data row3 col7" >0.9794</td>
#       <td id="T_4eea1_row3_col8" class="data row3 col8" >1.5320</td>
#     </tr>
#     <tr>
#       <th id="T_4eea1_level0_row4" class="row_heading level0 row4" >rf</th>
#       <td id="T_4eea1_row4_col0" class="data row4 col0" >Random Forest Classifier</td>
#       <td id="T_4eea1_row4_col1" class="data row4 col1" >0.9897</td>
#       <td id="T_4eea1_row4_col2" class="data row4 col2" >0.9985</td>
#       <td id="T_4eea1_row4_col3" class="data row4 col3" >0.9916</td>
#       <td id="T_4eea1_row4_col4" class="data row4 col4" >0.9897</td>
#       <td id="T_4eea1_row4_col5" class="data row4 col5" >0.9906</td>
#       <td id="T_4eea1_row4_col6" class="data row4 col6" >0.9792</td>
#       <td id="T_4eea1_row4_col7" class="data row4 col7" >0.9792</td>
#       <td id="T_4eea1_row4_col8" class="data row4 col8" >1.8200</td>
#     </tr>
#     <tr>
#       <th id="T_4eea1_level0_row5" class="row_heading level0 row5" >qda</th>
#       <td id="T_4eea1_row5_col0" class="data row5 col0" >Quadratic Discriminant Analysis</td>
#       <td id="T_4eea1_row5_col1" class="data row5 col1" >0.9893</td>
#       <td id="T_4eea1_row5_col2" class="data row5 col2" >0.9983</td>
#       <td id="T_4eea1_row5_col3" class="data row5 col3" >0.9943</td>
#       <td id="T_4eea1_row5_col4" class="data row5 col4" >0.9864</td>
# Processing:   0%|          | 0/65 [00:00<?, ?it/s]
