# %% [markdown]
# <a href="https://colab.research.google.com/github/a-donat/Benchmarks_PyCaret/blob/main/Predicting_Urban_Water_Quality.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # I. Set-Up

# %% [markdown]
# ## I.A. Import Libraries and Download Data

# %%
! pip install kaggle
! mkdir ~/.kaggle
! cp kaggle.json ~/.kaggle/
! chmod 600 ~/.kaggle/kaggle.json
! kaggle datasets download -d mssmartypants/water-quality
! unzip '/content/water-quality.zip' -d '/content/data'

# %%
! pip install pycaret

# %%
#import matplotlib.pyplot as plt
#import seaborn as sns
import VisualizeDataAbbrev as viz

import numpy as np
import pandas as pd
from pycaret.classification import *
from sklearn.model_selection import train_test_split

# %% [markdown]
# ## I.B. Load Data and Check Data Integrity

# %%
ds_df = pd.read_csv("/content/data/waterQuality1.csv")

# %%
ds_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7999 entries, 0 to 7998
# Data columns (total 21 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   aluminium    7999 non-null   float64
#  1   ammonia      7999 non-null   object
#  2   arsenic      7999 non-null   float64
#  3   barium       7999 non-null   float64
#  4   cadmium      7999 non-null   float64
#  5   chloramine   7999 non-null   float64
#  6   chromium     7999 non-null   float64
#  7   copper       7999 non-null   float64
#  8   flouride     7999 non-null   float64
#  9   bacteria     7999 non-null   float64
#  10  viruses      7999 non-null   float64
#  11  lead         7999 non-null   float64
#  12  nitrates     7999 non-null   float64
#  13  nitrites     7999 non-null   float64
#  14  mercury      7999 non-null   float64
#  15  perchlorate  7999 non-null   float64
#  16  radium       7999 non-null   float64
#  17  selenium     7999 non-null   float64
#  18  silver       7999 non-null   float64
#  19  uranium      7999 non-null   float64
#  20  is_safe      7999 non-null   object
# dtypes: float64(19), object(2)
# memory usage: 1.3+ MB

# %%
ds_df.nunique()
# Out:
# aluminium       495
# ammonia        2564
# arsenic         107
# barium          480
# cadmium          23
# chloramine      812
# chromium         91
# copper          201
# flouride        151
# bacteria        101
# viruses          61
# lead            200
# nitrates       1803
# nitrites        280
# mercury          11
# perchlorate    2999
# radium          735
# selenium         11
# silver           51
# uranium          10
# is_safe           3
# dtype: int64

# %%
ds_df["is_safe"].value_counts()
# Out:
# 0        7084
# 1         912
# #NUM!       3
# Name: is_safe, dtype: int64

# %%
ds_df[ds_df["is_safe"]=="#NUM!"]
# Out:
#       aluminium ammonia  arsenic  barium  cadmium  chloramine  chromium  \
# 7551       0.03   #NUM!     0.08    0.79     0.07        0.08      0.05
# 7568       0.06   #NUM!     0.07    1.72     0.08        0.32      0.01
# 7890       0.01   #NUM!     0.08    0.49     0.00        0.07      0.09
#
#       copper  flouride  bacteria  ...   lead  nitrates  nitrites  mercury  \
# 7551    0.58      0.34      0.00  ...  0.183      4.37      1.43    0.007
# 7568    1.11      0.61      0.00  ...  0.178     12.10      2.03    0.008
# 7890    0.06      0.72      0.57  ...  0.088      9.57      1.45    0.009
#
#       perchlorate  radium  selenium  silver  uranium  is_safe
# 7551         0.62    2.54      0.07    0.05     0.05    #NUM!
# 7568         1.37    2.05      0.06    0.10     0.07    #NUM!
# 7890         7.67    7.70      0.03    0.05     0.02    #NUM!
#
# [3 rows x 21 columns]

# %%
ds_df = ds_df[ds_df["is_safe"]!="#NUM!"].copy()
ds_df["ammonia"] = ds_df["ammonia"].astype(float)
ds_df["is_safe"] = ds_df["ammonia"].astype(int)

# %%
ds_df.describe().round(5)
# Out:
#         aluminium     ammonia     arsenic      barium     cadmium  chloramine  \
# count  7996.00000  7996.00000  7996.00000  7996.00000  7996.00000  7996.00000
# mean      0.66640    14.27821     0.16148     1.56793     0.04280     2.17759
# std       1.26532     8.87893     0.25263     1.21623     0.03605     2.56721
# min       0.00000    -0.08000     0.00000     0.00000     0.00000     0.00000
# 25%       0.04000     6.57750     0.03000     0.56000     0.00800     0.10000
# 50%       0.07000    14.13000     0.05000     1.19000     0.04000     0.53000
# 75%       0.28000    22.13250     0.10000     2.48250     0.07000     4.24000
# max       5.05000    29.84000     1.05000     4.94000     0.13000     8.68000
#
#          chromium      copper    flouride    bacteria  ...        lead  \
# count  7996.00000  7996.00000  7996.00000  7996.00000  ...  7996.00000
# mean      0.24730     0.80594     0.77165     0.31971  ...     0.09943
# std       0.27066     0.65359     0.43542     0.32950  ...     0.05817
# min       0.00000     0.00000     0.00000     0.00000  ...     0.00000
# 25%       0.05000     0.09000     0.40750     0.00000  ...     0.04800
# 50%       0.09000     0.75000     0.77000     0.22000  ...     0.10200
# 75%       0.44000     1.39000     1.16000     0.61000  ...     0.15100
# max       0.90000     2.00000     1.50000     1.00000  ...     0.20000
#
#          nitrates    nitrites     mercury  perchlorate      radium  \
# count  7996.00000  7996.00000  7996.00000   7996.00000  7996.00000
# mean      9.81925     1.32985     0.00519     16.46527     2.92011
# std       5.54198     0.57327     0.00297     17.68883     2.32281
# min       0.00000     0.00000     0.00000      0.00000     0.00000
# 25%       5.00000     1.00000     0.00300      2.17000     0.82000
# 50%       9.93000     1.42000     0.00500      7.74500     2.41000
# 75%      14.61000     1.76000     0.00800     29.48750     4.67000
# max      19.83000     2.93000     0.01000     60.01000     7.99000
#
#          selenium      silver     uranium     is_safe
# count  7996.00000  7996.00000  7996.00000  7996.00000
# mean      0.04968     0.14781     0.04467    13.78914
# std       0.02877     0.14357     0.02691     8.87189
# min       0.00000     0.00000     0.00000     0.00000
# 25%       0.02000     0.04000     0.02000     6.00000
# 50%       0.05000     0.08000     0.05000    14.00000
# 75%       0.07000     0.24000     0.07000    22.00000
# max       0.10000     0.50000     0.09000    29.00000
#
# [8 rows x 21 columns]

# %% [markdown]
# # II. Preprocessing

# %%
train_df, test_df = train_test_split(
    ds_df, test_size=0.20, stratify=ds_df["is_safe"], random_state=1)

# %% [markdown]
# # III. Create Models

# %%
exp_clf101 = setup(data=train_df, target = "is_safe", session_id=123,
                   fix_imbalance=True)
# Out:
# <style type="text/css">
# #T_43283_row8_col1, #T_43283_row12_col1 {
#   background-color: lightgreen;
# }
# </style>
# <table id="T_43283" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_43283_level0_col0" class="col_heading level0 col0" >Description</th>
#       <th id="T_43283_level0_col1" class="col_heading level0 col1" >Value</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_43283_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_43283_row0_col0" class="data row0 col0" >Session id</td>
#       <td id="T_43283_row0_col1" class="data row0 col1" >123</td>
#     </tr>
#     <tr>
#       <th id="T_43283_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_43283_row1_col0" class="data row1 col0" >Target</td>
#       <td id="T_43283_row1_col1" class="data row1 col1" >is_safe</td>
#     </tr>
#     <tr>
#       <th id="T_43283_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_43283_row2_col0" class="data row2 col0" >Target type</td>
#       <td id="T_43283_row2_col1" class="data row2 col1" >Multiclass</td>
#     </tr>
#     <tr>
#       <th id="T_43283_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_43283_row3_col0" class="data row3 col0" >Original data shape</td>
#       <td id="T_43283_row3_col1" class="data row3 col1" >(6396, 21)</td>
#     </tr>
#     <tr>
#       <th id="T_43283_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_43283_row4_col0" class="data row4 col0" >Transformed data shape</td>
#       <td id="T_43283_row4_col1" class="data row4 col1" >(11189, 21)</td>
#     </tr>
#     <tr>
#       <th id="T_43283_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_43283_row5_col0" class="data row5 col0" >Transformed train set shape</td>
#       <td id="T_43283_row5_col1" class="data row5 col1" >(9270, 21)</td>
#     </tr>
#     <tr>
#       <th id="T_43283_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_43283_row6_col0" class="data row6 col0" >Transformed test set shape</td>
#       <td id="T_43283_row6_col1" class="data row6 col1" >(1919, 21)</td>
#     </tr>
#     <tr>
#       <th id="T_43283_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_43283_row7_col0" class="data row7 col0" >Numeric features</td>
#       <td id="T_43283_row7_col1" class="data row7 col1" >20</td>
#     </tr>
#     <tr>
#       <th id="T_43283_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_43283_row8_col0" class="data row8 col0" >Preprocess</td>
#       <td id="T_43283_row8_col1" class="data row8 col1" >True</td>
#     </tr>
#     <tr>
#       <th id="T_43283_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_43283_row9_col0" class="data row9 col0" >Imputation type</td>
#       <td id="T_43283_row9_col1" class="data row9 col1" >simple</td>
#     </tr>
#     <tr>
#       <th id="T_43283_level0_row10" class="row_heading level0 row10" >10</th>
#       <td id="T_43283_row10_col0" class="data row10 col0" >Numeric imputation</td>
#       <td id="T_43283_row10_col1" class="data row10 col1" >mean</td>
#     </tr>
#     <tr>
#       <th id="T_43283_level0_row11" class="row_heading level0 row11" >11</th>
#       <td id="T_43283_row11_col0" class="data row11 col0" >Categorical imputation</td>
#       <td id="T_43283_row11_col1" class="data row11 col1" >mode</td>
#     </tr>
#     <tr>
#       <th id="T_43283_level0_row12" class="row_heading level0 row12" >12</th>
#       <td id="T_43283_row12_col0" class="data row12 col0" >Fix imbalance</td>
#       <td id="T_43283_row12_col1" class="data row12 col1" >True</td>
#     </tr>
#     <tr>
#       <th id="T_43283_level0_row13" class="row_heading level0 row13" >13</th>
#       <td id="T_43283_row13_col0" class="data row13 col0" >Fix imbalance method</td>
#       <td id="T_43283_row13_col1" class="data row13 col1" >SMOTE</td>
#     </tr>
#     <tr>
#       <th id="T_43283_level0_row14" class="row_heading level0 row14" >14</th>
#       <td id="T_43283_row14_col0" class="data row14 col0" >Fold Generator</td>
#       <td id="T_43283_row14_col1" class="data row14 col1" >StratifiedKFold</td>
#     </tr>
#     <tr>
#       <th id="T_43283_level0_row15" class="row_heading level0 row15" >15</th>
#       <td id="T_43283_row15_col0" class="data row15 col0" >Fold Number</td>
#       <td id="T_43283_row15_col1" class="data row15 col1" >10</td>
#     </tr>
#     <tr>
#       <th id="T_43283_level0_row16" class="row_heading level0 row16" >16</th>
#       <td id="T_43283_row16_col0" class="data row16 col0" >CPU Jobs</td>
#       <td id="T_43283_row16_col1" class="data row16 col1" >-1</td>
#     </tr>
#     <tr>
#       <th id="T_43283_level0_row17" class="row_heading level0 row17" >17</th>
#       <td id="T_43283_row17_col0" class="data row17 col0" >Use GPU</td>
#       <td id="T_43283_row17_col1" class="data row17 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_43283_level0_row18" class="row_heading level0 row18" >18</th>
#       <td id="T_43283_row18_col0" class="data row18 col0" >Log Experiment</td>
#       <td id="T_43283_row18_col1" class="data row18 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_43283_level0_row19" class="row_heading level0 row19" >19</th>
#       <td id="T_43283_row19_col0" class="data row19 col0" >Experiment Name</td>
#       <td id="T_43283_row19_col1" class="data row19 col1" >clf-default-name</td>
#     </tr>
#     <tr>
#       <th id="T_43283_level0_row20" class="row_heading level0 row20" >20</th>
#       <td id="T_43283_row20_col0" class="data row20 col0" >USI</td>
#       <td id="T_43283_row20_col1" class="data row20 col1" >23d5</td>
#     </tr>
#   </tbody>
# </table>

# %%
best_model = compare_models(fold=5)
# Out:
# <style type="text/css">
# #T_0f61b th {
#   text-align: left;
# }
# #T_0f61b_row0_col0, #T_0f61b_row0_col2, #T_0f61b_row1_col0, #T_0f61b_row1_col1, #T_0f61b_row1_col2, #T_0f61b_row1_col3, #T_0f61b_row1_col4, #T_0f61b_row1_col5, #T_0f61b_row1_col6, #T_0f61b_row1_col7, #T_0f61b_row2_col0, #T_0f61b_row2_col1, #T_0f61b_row2_col2, #T_0f61b_row2_col3, #T_0f61b_row2_col4, #T_0f61b_row2_col5, #T_0f61b_row2_col6, #T_0f61b_row
row0_col0" class="data row0 col0" >Extreme Gradient Boosting</td>
#       <td id="T_0f61b_row0_col1" class="data row0 col1" >0.9958</td>
#       <td id="T_0f61b_row0_col2" class="data row0 col2" >0.9995</td>
#       <td id="T_0f61b_row0_col3" class="data row0 col3" >0.9958</td>
#       <td id="T_0f61b_row0_col4" class="data row0 col4" >0.9959</td>
#       <td id="T_0f61b_row0_col5" class="data row0 col5" >0.9958</td>
#       <td id="T_0f61b_row0_col6" class="data row0 col6" >0.9956</td>
#       <td id="T_0f61b_row0_col7" class="data row0 col7" >0.9956</td>
#       <td id="T_0f61b_row0_col8" class="data row0 col8" >10.0140</td>
#     </tr>
#     <tr>
#       <th id="T_0f61b_level0_row1" class="row_heading level0 row1" >dt</th>
#       <td id="T_0f61b_row1_col0" class="data row1 col0" >Decision Tree Classifier</td>
#       <td id="T_0f61b_row1_col1" class="data row1 col1" >0.9955</td>
#       <td id="T_0f61b_row1_col2" class="data row1 col2" >0.9977</td>
#       <td id="T_0f61b_row1_col3" class="data row1 col3" >0.9955</td>
#       <td id="T_0f61b_row1_col4" class="data row1 col4" >0.9957</td>
#       <td id="T_0f61b_row1_col5" class="data row1 col5" >0.9955</td>
#       <td id="T_0f61b_row1_col6" class="data row1 col6" >0.9954</td>
#       <td id="T_0f61b_row1_col7" class="data row1 col7" >0.9954</td>
#       <td id="T_0f61b_row1_col8" class="data row1 col8" >0.6980</td>
#     </tr>
#     <tr>
#       <th id="T_0f61b_level0_row2" class="row_heading level0 row2" >gbc</th>
#       <td id="T_0f61b_row2_col0" class="data row2 col0" >Gradient Boosting Classifier</td>
#       <td id="T_0f61b_row2_col1" class="data row2 col1" >0.9955</td>
#       <td id="T_0f61b_row2_col2" class="data row2 col2" >0.9977</td>
#       <td id="T_0f61b_row2_col3" class="data row2 col3" >0.9955</td>
#       <td id="T_0f61b_row2_col4" class="data row2 col4" >0.9957</td>
#       <td id="T_0f61b_row2_col5" class="data row2 col5" >0.9955</td>
#       <td id="T_0f61b_row2_col6" class="data row2 col6" >0.9954</td>
#       <td id="T_0f61b_row2_col7" class="data row2 col7" >0.9954</td>
#       <td id="T_0f61b_row2_col8" class="data row2 col8" >55.9340</td>
#     </tr>
#     <tr>
#       <th id="T_0f61b_level0_row3" class="row_heading level0 row3" >lda</th>
#       <td id="T_0f61b_row3_col0" class="data row3 col0" >Linear Discriminant Analysis</td>
#       <td id="T_0f61b_row3_col1" class="data row3 col1" >0.9535</td>
#       <td id="T_0f61b_row3_col2" class="data row3 col2" >0.9998</td>
#       <td id="T_0f61b_row3_col3" class="data row3 col3" >0.9535</td>
#       <td id="T_0f61b_row3_col4" class="data row3 col4" >0.9552</td>
#       <td id="T_0f61b_row3_col5" class="data row3 col5" >0.9534</td>
#       <td id="T_0f61b_row3_col6" class="data row3 col6" >0.9518</td>
#       <td id="T_0f61b_row3_col7" class="data row3 col7" >0.9519</td>
#       <td id="T_0f61b_row3_col8" class="data row3 col8" >0.1380</td>
#     </tr>
#     <tr>
#       <th id="T_0f61b_level0_row4" class="row_heading level0 row4" >lightgbm</th>
#       <td id="T_0f61b_row4_col0" class="data row4 col0" >Light Gradient Boosting Machine</td>
#       <td id="T_0f61b_row4_col1" class="data row4 col1" >0.9535</td>
#       <td id="T_0f61b_row4_col2" class="data row4 col2" >0.9996</td>
#       <td id="T_0f61b_row4_col3" class="data row4 col3" >0.9535</td>
#       <td id="T_0f61b_row4_col4" class="data row4 col4" >0.9557</td>
#       <td id="T_0f61b_row4_col5" class="data row4 col5" >0.9536</td>
#       <td id="T_0f61b_row4_col6" class="data row4 col6" >0.9518</td>
#       <td id="T_0f61b_row4_col7" class="data row4 col7" >0.9519</td>
#       <td id="T_0f61b_row4_col8" class="data row4 col8" >8.6880</td>
#     </tr>
#     <tr>
#       <th id="T_0f61b_level0_row5" class="row_heading level0 row5" >nb</th>
#       <td id="T_0f61b_row5_col0" class="data row5 col0" >Naive Bayes</td>
#       <td id="T_0f61b_row5_col1" class="data row5 col1" >0.9261</td>
#       <td id="T_0f61b_row5_col2" class="data row5 col2" >0.9993</td>
#       <td id="T_0f61b_row5_col3" class="data row5 col3" >0.9261</td>
#       <td id="T_0f61b_row5_col4" class="data row5 col4" >0.9281</
# Processing:   0%|          | 0/65 [00:00<?, ?it/s]
