# %% [markdown]
# <a href="https://colab.research.google.com/github/a-donat/Benchmarks_PyCaret/blob/main/Predicting_Room_Occupancy.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # I. Set-Up

# %% [markdown]
# ## I.A. Import Libraries and Download Data

# %%
! pip install kaggle
! mkdir ~/.kaggle
! cp kaggle.json ~/.kaggle/
! chmod 600 ~/.kaggle/kaggle.json
! kaggle datasets download -d sachinsharma1123/room-occupancy
! unzip '/content/room-occupancy.zip' -d '/content/data'

# %%
! pip install pycaret

# %%
#import matplotlib.pyplot as plt
#import seaborn as sns
import VisualizeDataAbbrev as viz

import numpy as np
import pandas as pd
from pycaret.classification import *
from sklearn.model_selection import train_test_split

# %% [markdown]
# ## I.B. Load Data and Check Data Integrity

# %%
ro_df = pd.read_csv("/content/data/file.csv")

# %%
ro_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2665 entries, 0 to 2664
# Data columns (total 6 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Temperature    2665 non-null   float64
#  1   Humidity       2665 non-null   float64
#  2   Light          2665 non-null   float64
#  3   CO2            2665 non-null   float64
#  4   HumidityRatio  2665 non-null   float64
#  5   Occupancy      2665 non-null   int64
# dtypes: float64(5), int64(1)
# memory usage: 125.0 KB

# %%
ro_df.describe().round(5)
# Out:
#        Temperature    Humidity       Light         CO2  HumidityRatio  \
# count   2665.00000  2665.00000  2665.00000  2665.00000     2665.00000
# mean      21.43388    25.35394   193.22756   717.90647        0.00403
# std        1.02802     2.43684   250.21091   292.68172        0.00061
# min       20.20000    22.10000     0.00000   427.50000        0.00330
# 25%       20.65000    23.26000     0.00000   466.00000        0.00353
# 50%       20.89000    25.00000     0.00000   580.50000        0.00382
# 75%       22.35667    26.85667   442.50000   956.33333        0.00453
# max       24.40833    31.47250  1697.25000  1402.25000        0.00538
#
#         Occupancy
# count  2665.00000
# mean      0.36473
# std       0.48144
# min       0.00000
# 25%       0.00000
# 50%       0.00000
# 75%       1.00000
# max       1.00000

# %%
ro_df.nunique()
# Out:
# Temperature       335
# Humidity          725
# Light             428
# CO2              1894
# HumidityRatio    1505
# Occupancy           2
# dtype: int64

# %% [markdown]
# # II. Preprocessing

# %%
ro_train_df, ro_test_df = train_test_split(
    ro_df, test_size=0.20, stratify=ro_df["Occupancy"], random_state=1)

# %% [markdown]
# # III. Create Models

# %%
exp_clf101 = setup(data=ro_train_df, target = "Occupancy", session_id=123)
# Out:
# <style type="text/css">
# #T_b6217_row8_col1 {
#   background-color: lightgreen;
# }
# </style>
# <table id="T_b6217" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_b6217_level0_col0" class="col_heading level0 col0" >Description</th>
#       <th id="T_b6217_level0_col1" class="col_heading level0 col1" >Value</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_b6217_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_b6217_row0_col0" class="data row0 col0" >Session id</td>
#       <td id="T_b6217_row0_col1" class="data row0 col1" >123</td>
#     </tr>
#     <tr>
#       <th id="T_b6217_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_b6217_row1_col0" class="data row1 col0" >Target</td>
#       <td id="T_b6217_row1_col1" class="data row1 col1" >Occupancy</td>
#     </tr>
#     <tr>
#       <th id="T_b6217_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_b6217_row2_col0" class="data row2 col0" >Target type</td>
#       <td id="T_b6217_row2_col1" class="data row2 col1" >Binary</td>
#     </tr>
#     <tr>
#       <th id="T_b6217_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_b6217_row3_col0" class="data row3 col0" >Original data shape</td>
#       <td id="T_b6217_row3_col1" class="data row3 col1" >(2132, 6)</td>
#     </tr>
#     <tr>
#       <th id="T_b6217_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_b6217_row4_col0" class="data row4 col0" >Transformed data shape</td>
#       <td id="T_b6217_row4_col1" class="data row4 col1" >(2132, 6)</td>
#     </tr>
#     <tr>
#       <th id="T_b6217_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_b6217_row5_col0" class="data row5 col0" >Transformed train set shape</td>
#       <td id="T_b6217_row5_col1" class="data row5 col1" >(1492, 6)</td>
#     </tr>
#     <tr>
#       <th id="T_b6217_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_b6217_row6_col0" class="data row6 col0" >Transformed test set shape</td>
#       <td id="T_b6217_row6_col1" class="data row6 col1" >(640, 6)</td>
#     </tr>
#     <tr>
#       <th id="T_b6217_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_b6217_row7_col0" class="data row7 col0" >Numeric features</td>
#       <td id="T_b6217_row7_col1" class="data row7 col1" >5</td>
#     </tr>
#     <tr>
#       <th id="T_b6217_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_b6217_row8_col0" class="data row8 col0" >Preprocess</td>
#       <td id="T_b6217_row8_col1" class="data row8 col1" >True</td>
#     </tr>
#     <tr>
#       <th id="T_b6217_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_b6217_row9_col0" class="data row9 col0" >Imputation type</td>
#       <td id="T_b6217_row9_col1" class="data row9 col1" >simple</td>
#     </tr>
#     <tr>
#       <th id="T_b6217_level0_row10" class="row_heading level0 row10" >10</th>
#       <td id="T_b6217_row10_col0" class="data row10 col0" >Numeric imputation</td>
#       <td id="T_b6217_row10_col1" class="data row10 col1" >mean</td>
#     </tr>
#     <tr>
#       <th id="T_b6217_level0_row11" class="row_heading level0 row11" >11</th>
#       <td id="T_b6217_row11_col0" class="data row11 col0" >Categorical imputation</td>
#       <td id="T_b6217_row11_col1" class="data row11 col1" >mode</td>
#     </tr>
#     <tr>
#       <th id="T_b6217_level0_row12" class="row_heading level0 row12" >12</th>
#       <td id="T_b6217_row12_col0" class="data row12 col0" >Fold Generator</td>
#       <td id="T_b6217_row12_col1" class="data row12 col1" >StratifiedKFold</td>
#     </tr>
#     <tr>
#       <th id="T_b6217_level0_row13" class="row_heading level0 row13" >13</th>
#       <td id="T_b6217_row13_col0" class="data row13 col0" >Fold Number</td>
#       <td id="T_b6217_row13_col1" class="data row13 col1" >10</td>
#     </tr>
#     <tr>
#       <th id="T_b6217_level0_row14" class="row_heading level0 row14" >14</th>
#       <td id="T_b6217_row14_col0" class="data row14 col0" >CPU Jobs</td>
#       <td id="T_b6217_row14_col1" class="data row14 col1" >-1</td>
#     </tr>
#     <tr>
#       <th id="T_b6217_level0_row15" class="row_heading level0 row15" >15</th>
#       <td id="T_b6217_row15_col0" class="data row15 col0" >Use GPU</td>
#       <td id="T_b6217_row15_col1" class="data row15 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_b6217_level0_row16" class="row_heading level0 row16" >16</th>
#       <td id="T_b6217_row16_col0" class="data row16 col0" >Log Experiment</td>
#       <td id="T_b6217_row16_col1" class="data row16 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_b6217_level0_row17" class="row_heading level0 row17" >17</th>
#       <td id="T_b6217_row17_col0" class="data row17 col0" >Experiment Name</td>
#       <td id="T_b6217_row17_col1" class="data row17 col1" >clf-default-name</td>
#     </tr>
#     <tr>
#       <th id="T_b6217_level0_row18" class="row_heading level0 row18" >18</th>
#       <td id="T_b6217_row18_col0" class="data row18 col0" >USI</td>
#       <td id="T_b6217_row18_col1" class="data row18 col1" >2e0d</td>
#     </tr>
#   </tbody>
# </table>

# %%
best_model = compare_models()
# Out:
# <style type="text/css">
# #T_02a40 th {
#   text-align: left;
# }
# #T_02a40_row0_col0, #T_02a40_row0_col2, #T_02a40_row0_col3, #T_02a40_row1_col0, #T_02a40_row1_col1, #T_02a40_row1_col2, #T_02a40_row1_col3, #T_02a40_row1_col4, #T_02a40_row1_col5, #T_02a40_row1_col6, #T_02a40_row1_col7, #T_02a40_row2_col0, #T_02a40_row2_col1, #T_02a40_row2_col2, #T_02a40_row2_col3, #T_02a40_row2_col4, #T_02a40_row2_col5, #T_02a40_row2_col6, #T_02a40_row2_col7, #T_02a40_row3_
row0_col0" class="data row0 col0" >Extra Trees Classifier</td>
#       <td id="T_02a40_row0_col1" class="data row0 col1" >0.9913</td>
#       <td id="T_02a40_row0_col2" class="data row0 col2" >0.9977</td>
#       <td id="T_02a40_row0_col3" class="data row0 col3" >0.9908</td>
#       <td id="T_02a40_row0_col4" class="data row0 col4" >0.9855</td>
#       <td id="T_02a40_row0_col5" class="data row0 col5" >0.9881</td>
#       <td id="T_02a40_row0_col6" class="data row0 col6" >0.9812</td>
#       <td id="T_02a40_row0_col7" class="data row0 col7" >0.9813</td>
#       <td id="T_02a40_row0_col8" class="data row0 col8" >0.3510</td>
#     </tr>
#     <tr>
#       <th id="T_02a40_level0_row1" class="row_heading level0 row1" >dt</th>
#       <td id="T_02a40_row1_col0" class="data row1 col0" >Decision Tree Classifier</td>
#       <td id="T_02a40_row1_col1" class="data row1 col1" >0.9886</td>
#       <td id="T_02a40_row1_col2" class="data row1 col2" >0.9883</td>
#       <td id="T_02a40_row1_col3" class="data row1 col3" >0.9871</td>
#       <td id="T_02a40_row1_col4" class="data row1 col4" >0.9819</td>
#       <td id="T_02a40_row1_col5" class="data row1 col5" >0.9844</td>
#       <td id="T_02a40_row1_col6" class="data row1 col6" >0.9754</td>
#       <td id="T_02a40_row1_col7" class="data row1 col7" >0.9756</td>
#       <td id="T_02a40_row1_col8" class="data row1 col8" >0.0450</td>
#     </tr>
#     <tr>
#       <th id="T_02a40_level0_row2" class="row_heading level0 row2" >gbc</th>
#       <td id="T_02a40_row2_col0" class="data row2 col0" >Gradient Boosting Classifier</td>
#       <td id="T_02a40_row2_col1" class="data row2 col1" >0.9880</td>
#       <td id="T_02a40_row2_col2" class="data row2 col2" >0.9968</td>
#       <td id="T_02a40_row2_col3" class="data row2 col3" >0.9927</td>
#       <td id="T_02a40_row2_col4" class="data row2 col4" >0.9751</td>
#       <td id="T_02a40_row2_col5" class="data row2 col5" >0.9837</td>
#       <td id="T_02a40_row2_col6" class="data row2 col6" >0.9741</td>
#       <td id="T_02a40_row2_col7" class="data row2 col7" >0.9744</td>
#       <td id="T_02a40_row2_col8" class="data row2 col8" >0.3070</td>
#     </tr>
#     <tr>
#       <th id="T_02a40_level0_row3" class="row_heading level0 row3" >rf</th>
#       <td id="T_02a40_row3_col0" class="data row3 col0" >Random Forest Classifier</td>
#       <td id="T_02a40_row3_col1" class="data row3 col1" >0.9879</td>
#       <td id="T_02a40_row3_col2" class="data row3 col2" >0.9986</td>
#       <td id="T_02a40_row3_col3" class="data row3 col3" >0.9927</td>
#       <td id="T_02a40_row3_col4" class="data row3 col4" >0.9750</td>
#       <td id="T_02a40_row3_col5" class="data row3 col5" >0.9837</td>
#       <td id="T_02a40_row3_col6" class="data row3 col6" >0.9741</td>
#       <td id="T_02a40_row3_col7" class="data row3 col7" >0.9743</td>
#       <td id="T_02a40_row3_col8" class="data row3 col8" >0.4730</td>
#     </tr>
#     <tr>
#       <th id="T_02a40_level0_row4" class="row_heading level0 row4" >xgboost</th>
#       <td id="T_02a40_row4_col0" class="data row4 col0" >Extreme Gradient Boosting</td>
#       <td id="T_02a40_row4_col1" class="data row4 col1" >0.9879</td>
#       <td id="T_02a40_row4_col2" class="data row4 col2" >0.9961</td>
#       <td id="T_02a40_row4_col3" class="data row4 col3" >0.9908</td>
#       <td id="T_02a40_row4_col4" class="data row4 col4" >0.9767</td>
#       <td id="T_02a40_row4_col5" class="data row4 col5" >0.9836</td>
#       <td id="T_02a40_row4_col6" class="data row4 col6" >0.9741</td>
#       <td id="T_02a40_row4_col7" class="data row4 col7" >0.9742</td>
#       <td id="T_02a40_row4_col8" class="data row4 col8" >0.1610</td>
#     </tr>
#     <tr>
#       <th id="T_02a40_level0_row5" class="row_heading level0 row5" >lightgbm</th>
#       <td id="T_02a40_row5_col0" class="data row5 col0" >Light Gradient Boosting Machine</td>
#       <td id="T_02a40_row5_col1" class="data row5 col1" >0.9873</td>
#       <td id="T_02a40_row5_col2" class="data row5 col2" >0.9972</td>
#       <td id="T_02a40_row5_col3" class="data row5 col3" >0.9890</td>
#       <td id="T_02a40_row5_col4" class="data row5 col4" >0.97
# Processing:   0%|          | 0/65 [00:00<?, ?it/s]
